# %%
# %matplotlib inline
import torch
import numpy as np
import matplotlib.pylab as plt
import sys
sys.path.append('..')
import d2lzh_pytorch as d2l

# %%
def xyplot(x_vals,y_vals,name):
    d2l.set_figsize(figsize=(5,2.5))
    d2l.plt.plot(x_vals.detach().numpy(),y_vals.detach().numpy())
    d2l.plt.xlabel('x')
    d2l.plt.ylabel(name+'(x)')

# %%
x = torch.arange(-8.0,8.0,0.1,requires_grad=True)
y = x.relu()
y.sum().backward()
xyplot(x,x.grad,'relu')

# %%
xyplot(x,y,'re')

# %%
y = x.sigmoid()
xyplot(x,y,'aaaa')

# %%
x.grad.zero_()
y.sum().backward(retain_graph=True)
xyplot(x,x.grad,'aa')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-654b3a88fb21> in <module>
#       1 x.grad.zero_()
# ----> 2 y.sum().backward(retain_graph=True)
#       3 xyplot(x,x.grad,'aa')
#
# D:\ruanjian\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     196                 products. Defaults to ``False``.
#     197         """
# --> 198         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     199
#     200     def register_hook(self, hook):
#
# D:\ruanjian\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      98     Variable._execution_engine.run_backward(
#      99         tensors, grad_tensors, retain_graph, create_graph,
# --> 100         allow_unreachable=True)  # allow_unreachable flag
#     101
#     102
#
# RuntimeError: Trying to backward through the graph a second time, but the buffers have already been freed. Specify retain_graph=True when calling backward the first time.
